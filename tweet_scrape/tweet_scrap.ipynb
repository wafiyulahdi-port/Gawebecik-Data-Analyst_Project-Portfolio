# %%
# !curl -sL https://deb.nodesource.com/setup_18.x | sudo -E bash -
# !sudo apt-get install -y nodejs

# %%
data = 'tweet_data_2024.csv'
search_keyword = '#veganfood OR #vegan OR #Vegan OR #plantbased OR #PlantBased OR #veganism OR #govegan OR #veganfortheanimals OR #konsumsisayuran OR #konsumsisayur OR #konsumsisayur-sayuran OR #konsumsibuah OR #konsumsibuah-buahan OR #konsumsibiji-bijian until:2024-08-15 since:2024-01-01'
limit = 1000000000

# !npx --yes tweet-harvest@latest -o "{data}" -s "{search_keyword}"  -l {limit} --token ""
# Out:
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: '@playwright/test@1.46.0',
# npm WARN EBADENGINE   required: { node: '>=18' },
# npm WARN EBADENGINE   current: { node: 'v16.20.2', npm: '8.19.4' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: 'playwright@1.46.0',
# npm WARN EBADENGINE   required: { node: '>=18' },
# npm WARN EBADENGINE   current: { node: 'v16.20.2', npm: '8.19.4' }
# npm WARN EBADENGINE }
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: 'playwright-core@1.46.0',
# npm WARN EBADENGINE   required: { node: '>=18' },
# npm WARN EBADENGINE   current: { node: 'v16.20.2', npm: '8.19.4' }
# npm WARN EBADENGINE }
# npm WARN deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ...

# %%
import pandas as pd

data = pd.read_csv("/content/tweets-data/tweet_data_2024.csv")
data
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1821963805099769999  Fri Aug 09 17:36:36 +0000 2024              55
# 1    1822965280001200305  Mon Aug 12 11:56:06 +0000 2024             682
# 2    1821611150410440954  Thu Aug 08 18:15:16 +0000 2024             199
# 3    1820256984089948322  Mon Aug 05 00:34:18 +0000 2024            1235
# 4    1823408185849602414  Tue Aug 13 17:16:03 +0000 2024             136
# ..                   ...                             ...             ...
# 195  1744682194273235290  Tue Jan 09 11:27:04 +0000 2024               0
# 196  1744554644813017164  Tue Jan 09 03:00:14 +0000 2024               0
# 197  1744525989600985458  Tue Jan 09 01:06:22 +0000 2024               0
# 198  1744471987207213466  Mon Jan 08 21:31:47 +0000 2024               2
# 199  1744619341293723927  Tue Jan 09 07:17:19 +0000 2024              10
#
#                                              full_text               id_str  \
# ...
